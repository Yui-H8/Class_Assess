# %% [markdown]
# ### Lesson 3
# Selecting, sorting, and working
# with dates
# ---
# General instructions:
# Each section should be performed in a separate cell
#
#
# Part 1 - Data Selection
# 1. Open a new folder on your desktop named Python_Class
# 2. Go to the folder you opened, and create a new notebook called Ex_sol_3
# (Make sure that the notebook opens in the desired location)
# 3. Open a new cell and make it a Markdown cell
# 4. Write the following headline: Pandas - select dat
#
#
# 5. Import the Pandas Library to the notebook

# %%
import pandas as pd

# %% [markdown]
# 6. Import the data file 'hotel_bookings.csv', and save it in a variable named df.
# Make sure you import the data properly (dates, omitting unnecessary rows). Also, import the data in the reservation_no column so that it appears in the label index

# %%
df = pd.read_csv('hotel_bookings.csv',
                 index_col='reservation_no',
                 skiprows=3,skipfooter=1,
                 parse_dates=['reservation_status_date'],dayfirst=True)
# Out:
# C:\Users\hanay\AppData\Local\Temp\ipykernel_16848\3720691692.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv('hotel_bookings.csv',

# %% [markdown]
# 7. Show only the first 5 lines
# 8. Show only the last 3 lines

# %%
df.head()
# Out:
#                        hotel  is_canceled  lead_time  arrival_date_year  \
# reservation_no
# 12603           Resort Hotel            0        342               2015
# 12604           Resort Hotel            0        737               2015
# 12605           Resort Hotel            0          7               2015
# 12606           Resort Hotel            0         13               2015
# 12607           Resort Hotel            0         14               2015
#
#                arrival_date_month  arrival_date_week_number  \
# reservation_no
# 12603                        July                        27
# 12604                        July                        27
# 12605                        July                        27
# 12606                        July                        27
# 12607                        July                        27
#
#                 arrival_date_day_of_month  stays_in_weekend_nights  \
# reservation_no
# ...

# %%
df.tail(3)
# Out:
#                      hotel  is_canceled  lead_time  arrival_date_year  \
# reservation_no
# 131990          City Hotel            0         34               2017
# 131991          City Hotel            0        109               2017
# 131992          City Hotel            0        205               2017
#
#                arrival_date_month  arrival_date_week_number  \
# reservation_no
# 131990                     August                        35
# 131991                     August                        35
# 131992                     August                        35
#
#                 arrival_date_day_of_month  stays_in_weekend_nights  \
# reservation_no
# 131990                                 31                        2
# 131991                                 31                        2
# 131992                                 29                        2
#
#                 stays_in_week_nights  adults  ...  deposit_type  agent  \
# ...

# %% [markdown]
# 9. Which label index contains the highest number of nights in the middle of the week?

# %%
df['stays_in_weekend_nights'].idxmax()
# Out:
# np.int64(26641)

# %% [markdown]
# 10. Show every label index row which contains the highest number of nights in the middle of the week

# %%
df.loc[df['stays_in_weekend_nights'].idxmax()]
# Out:
# hotel                                    Resort Hotel
# is_canceled                                         0
# lead_time                                         126
# arrival_date_year                                2016
# arrival_date_month                               July
# arrival_date_week_number                           28
# arrival_date_day_of_month                           5
# stays_in_weekend_nights                            19
# stays_in_week_nights                               50
# adults                                              1
# children                                          0.0
# babies                                              0
# meal                                               HB
# country                                           NaN
# market_segment                                 Direct
# distribution_channel                           Direct
# is_repeated_guest                                   0
# ...

# %% [markdown]
# 11. Display the name of the hotel with the lowest number of reserved nights on a weekend

# %%
df['stays_in_weekend_nights'].idxmin()
# Out:
# np.int64(12603)

# %%
df.loc[df['stays_in_weekend_nights'].idxmin(),'hotel']
# Out:
# 'Resort Hotel'

# %% [markdown]
# 12. Show the hotel name, arrival month, number of adults, and number of nights in the middle of the week but only for guests who arrived for a number of days above the middle of the week average.
# How many such orders are there?

# %%
df['stays_in_week_nights'].mean()
# Out:
# np.float64(2.500301532791691)

# %%
where = df['stays_in_week_nights'] > df['stays_in_week_nights'].mean()
df[where]
# Out:
#                        hotel  is_canceled  lead_time  arrival_date_year  \
# reservation_no
# 12611           Resort Hotel            1         85               2015
# 12612           Resort Hotel            1         75               2015
# 12613           Resort Hotel            1         23               2015
# 12614           Resort Hotel            0         35               2015
# 12615           Resort Hotel            0         68               2015
# ...                      ...          ...        ...                ...
# 131988            City Hotel            0         23               2017
# 131989            City Hotel            0        102               2017
# 131990            City Hotel            0         34               2017
# 131991            City Hotel            0        109               2017
# 131992            City Hotel            0        205               2017
#
#                arrival_date_month  arrival_date_week_number  \
# reservation_no
# ...

# %%
where = df['stays_in_week_nights'] > df['stays_in_week_nights'].mean()

df[where][['hotel','arrival_date_month','adults', 'stays_in_week_nights']]
# Out:
#                        hotel arrival_date_month  adults  stays_in_week_nights
# reservation_no
# 12611           Resort Hotel               July       2                     3
# 12612           Resort Hotel               July       2                     3
# 12613           Resort Hotel               July       2                     4
# 12614           Resort Hotel               July       2                     4
# 12615           Resort Hotel               July       2                     4
# ...                      ...                ...     ...                   ...
# 131988            City Hotel             August       2                     5
# 131989            City Hotel             August       3                     5
# 131990            City Hotel             August       2                     5
# 131991            City Hotel             August       2                     5
# 131992            City Hotel             August       2                     7
#
# ...

# %% [markdown]
# 13. Look at the reservation_status column, how many unique values are there in this column?

# %%
df['reservation_status'].value_counts()
# Out:
# reservation_status
# Check-Out    75166
# Canceled     43017
# No-Show       1207
# Name: count, dtype: int64

# %% [markdown]
# 14. Show the value which is repeated the most number of times, and the number of times it is repeated

# %%
df['reservation_status'].value_counts()[0]
# Out:
# C:\Users\hanay\AppData\Local\Temp\ipykernel_16848\2938708817.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['reservation_status'].value_counts()[0]
# np.int64(75166)

# %%
df['reservation_status'].value_counts().head(1)
# Out:
# reservation_status
# Check-Out    75166
# Name: count, dtype: int64

# %% [markdown]
# 15. Challenge:
# Run an assignment on a variable called ‘status’, on the value which is repeated most often, by only writing  code
# 16. Are the values in the Order Number column unique?

# %%
#16
df.index.is_unique
# Out:
# True

# %% [markdown]
# 17. What is the highest number of children in the reservations for which the customer arrived at the hotel?

# %%
#17
where = df['reservation_status'] == 'Check-Out'
df.loc[where, 'children'].max()
# Out:
# np.float64(3.0)

# %% [markdown]
# If you did the challenge in section 15, you can use the value in the status variable

# %% [markdown]
# ---
# #### Part 2 – Sorting, Handling columns, updating data and working with dates
# 18. Add a MARKDOWN cell and write the title Part 2 in it
# 19. Rename the following columns permanently to shorter names, as indicated:
# a. Arrival_date_year  → year
# b. arrival_date_month → month
# c. arrival_date_week_number → week
# d. arrival_date_day_of_month → day

# %%
import pandas as pd

# 19
clumns_to_change = {'arrival_date_year' : 'year',
                    'arrival_date_month' : 'month',
                    'arrival_date_week_number' : 'week',
                    'arrival_date_day_of_month' : 'day'}
df.info()

df.rename(columns=clumns_to_change, inplace=True)
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 119390 entries, 12603 to 131992
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.rename(columns=clumns_to_change, inplace=True)
df
# Out:
#                        hotel  is_canceled  lead_time  year   month  week  day  \
# reservation_no
# 12603           Resort Hotel            0        342  2015    July    27    1
# 12604           Resort Hotel            0        737  2015    July    27    1
# 12605           Resort Hotel            0          7  2015    July    27    1
# 12606           Resort Hotel            0         13  2015    July    27    1
# 12607           Resort Hotel            0         14  2015    July    27    1
# ...                      ...          ...        ...   ...     ...   ...  ...
# 131988            City Hotel            0         23  2017  August    35   30
# 131989            City Hotel            0        102  2017  August    35   31
# 131990            City Hotel            0         34  2017  August    35   31
# 131991            City Hotel            0        109  2017  August    35   31
# 131992            City Hotel            0        205  2017  August    35   29
#
# ...

# %% [markdown]
# 20. Display only the columns ‘Number of nights in the middle of the week’ and ‘Number of nights on the weekend’
# 21. Because we want to analyze the data for the total number of nights, define a new column called total_nights that will contain the number of nights in the middle of the week plus the weekend nights for each reservation row

# %%
df['total_nights'] = df['stays_in_week_nights'] + df['stays_in_weekend_nights']
df[['stays_in_week_nights', 'stays_in_weekend_nights', 'total_nights']]
# Out:
#                 stays_in_week_nights  stays_in_weekend_nights  total_nights
# reservation_no
# 12603                              0                        0             0
# 12604                              0                        0             0
# 12605                              1                        0             1
# 12606                              1                        0             1
# 12607                              2                        0             2
# ...                              ...                      ...           ...
# 131988                             5                        2             7
# 131989                             5                        2             7
# 131990                             5                        2             7
# 131991                             5                        2             7
# 131992                             7                        2             9
#
# [119390 rows x 3 columns]

# %% [markdown]
# 22. Check your answer, and see that a new column has indeed been added at the end of the df

# %%
df
# Out:
#                        hotel  is_canceled  lead_time  year   month  week  day  \
# reservation_no
# 12603           Resort Hotel            0        342  2015    July    27    1
# 12604           Resort Hotel            0        737  2015    July    27    1
# 12605           Resort Hotel            0          7  2015    July    27    1
# 12606           Resort Hotel            0         13  2015    July    27    1
# 12607           Resort Hotel            0         14  2015    July    27    1
# ...                      ...          ...        ...   ...     ...   ...  ...
# 131988            City Hotel            0         23  2017  August    35   30
# 131989            City Hotel            0        102  2017  August    35   31
# 131990            City Hotel            0         34  2017  August    35   31
# 131991            City Hotel            0        109  2017  August    35   31
# 131992            City Hotel            0        205  2017  August    35   29
#
# ...

# %% [markdown]
# 23. Show descriptive statistics (describe) for the Total Nights column.
# What is the average number of nights?
# What is the highest number of nights reserved?

# %%
df['total_nights'].describe()
# Out:
# count    119390.000000
# mean          3.427900
# std           2.557439
# min           0.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max          69.000000
# Name: total_nights, dtype: float64

# %% [markdown]
# 24. Sort the data by hotel and then by the total amount of nights from high to low. Set the sort so that it stays.
# View the data after sorting

# %%
df.sort_values(['hotel', 'total_nights'], ascending=[True, False], inplace=True)
df
# Out:
#                        hotel  is_canceled  lead_time  year      month  week  \
# reservation_no
# 114397            City Hotel            0        140  2016  September    39
# 100620            City Hotel            0         16  2016      March    11
# 67307             City Hotel            0        206  2016       July    30
# 119164            City Hotel            0         11  2017    January     3
# 115885            City Hotel            0          3  2016   November    47
# ...                      ...          ...        ...   ...        ...   ...
# 51379           Resort Hotel            0          0  2017       July    30
# 51570           Resort Hotel            0          0  2017     August    31
# 51980           Resort Hotel            0        204  2017     August    33
# 52130           Resort Hotel            0          0  2017     August    34
# 52455           Resort Hotel            0          0  2017     August    35
#
# ...

# %% [markdown]
# 25. Because the hotel looks at two groups of reservations - reservations where the guests have arrived at the hotel, and reservations which were canceled
#
#  - update all  reservations with the status No-Show to Canceled Check your answer

# %%
df['reservation_status'].value_counts()
# Out:
# reservation_status
# Check-Out    75166
# Canceled     43017
# No-Show       1207
# Name: count, dtype: int64

# %%
where = df['reservation_status'] == 'No-Show'
df.loc[where, 'reservation_status'] = 'Canceled'

df['reservation_status'].value_counts()
# Out:
# reservation_status
# Check-Out    75166
# Canceled     44224
# Name: count, dtype: int64

# %% [markdown]
# We will now work with new data - data on cars stopped by traffic police
# 26. Add a new title called PART-3
#
# ### PART-3

# %%
policedf = pd.read_csv('police.csv',
                 parse_dates=['stop_date'],dayfirst=True)
policedf
# Out:
#        stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0     2005-01-02      1:55          NaN             M          1985.0
# 1     2005-01-18      8:15          NaN             M          1965.0
# 2     2005-01-23     23:15          NaN             M          1972.0
# 3     2005-02-20     17:15          NaN             M          1986.0
# 4     2005-03-14     10:00          NaN             F          1984.0
# ...          ...       ...          ...           ...             ...
# 91736 2015-12-31     20:27          NaN             M          1986.0
# 91737 2015-12-31     20:35          NaN             F          1982.0
# 91738 2015-12-31     20:45          NaN             M          1992.0
# 91739 2015-12-31     21:42          NaN             M          1993.0
# 91740 2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# 0            20.0       White                        Speeding
# ...

# %% [markdown]
# 27. Import to the notebook the POLICE.csv file. Pay attention to the date column
# 28. Check that the date column was accepted correctly
# 29. Add a column that contains the year, taken from the date

# %%
policedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  datetime64[ns]
#  1   stop_time           91741 non-null  object
#  2   county_name         0 non-null      float64
#  3   driver_gender       86406 non-null  object
#  4   driver_age_raw      86414 non-null  float64
#  5   driver_age          86120 non-null  float64
#  6   driver_race         86408 non-null  object
#  7   violation_raw       86408 non-null  object
#  8   violation           86408 non-null  object
#  9   search_conducted    91741 non-null  bool
#  10  search_type         3196 non-null   object
#  11  stop_outcome        86408 non-null  object
#  12  is_arrested         86408 non-null  object
#  13  ticket_amount       1082 non-null   float64
#  14  stop_duration       86408 non-null  object
# ...

# %% [markdown]
# 29. Add a column that contains the year, taken from the date
# 30. Add a column that contains the month, taken from the date
# 31. Check that the columns have been added correctly and that they contain the correct information

# %%
# 29 - 31
policedf['stop_year'] = policedf['stop_date'].dt.year
policedf['stop_month'] = policedf['stop_date'].dt.month
policedf
# Out:
#        stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0     2005-01-02      1:55          NaN             M          1985.0
# 1     2005-01-18      8:15          NaN             M          1965.0
# 2     2005-01-23     23:15          NaN             M          1972.0
# 3     2005-02-20     17:15          NaN             M          1986.0
# 4     2005-03-14     10:00          NaN             F          1984.0
# ...          ...       ...          ...           ...             ...
# 91736 2015-12-31     20:27          NaN             M          1986.0
# 91737 2015-12-31     20:35          NaN             F          1982.0
# 91738 2015-12-31     20:45          NaN             M          1992.0
# 91739 2015-12-31     21:42          NaN             M          1993.0
# 91740 2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# 0            20.0       White                        Speeding
# ...
